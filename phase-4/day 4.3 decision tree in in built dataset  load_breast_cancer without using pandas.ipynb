# %%
-steps for decision tree:
        -load the data
        -define x and y
        -define x_train , x_test , y_train , y_test using (train_test_split)
            -x_train= training input data
            -x_test = testing  input data   
            -y_train= training result data
            -y_test = testing  result data  (ACTUAL VALUE)
            --x_pred= when x_train as input than prediction is x_pred
            --y_pred= when x_test as input than prediction is y_pred (PREDICTED VALUE)
        -making instance of linear regression 
            -regressor.fit(x_train,y_train)
        -define x_pred and, y_pred
        -confusion matrix
        -classification report
        -DECISION TREE
        -accuracy
# Out:
#   File "C:\Users\OM SAI\AppData\Local\Temp\ipykernel_4688\863290985.py", line 1
#     -steps fro decision tree:
#              ^
# SyntaxError: invalid syntax

# %%
from sklearn import datasets

# %%
data=datasets.load_breast_cancer()

# %%
x=data.data
y=data.target

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix  # show the errors
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[44  4]
#  [ 2 93]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94        48
#            1       0.96      0.98      0.97        95
#
#     accuracy                           0.96       143
#    macro avg       0.96      0.95      0.95       143
# weighted avg       0.96      0.96      0.96       143

# %%
from sklearn import tree
tree.plot_tree(clf)
# Out:
# [Text(0.6710526315789473, 0.9375, 'X[22] <= 113.15\ngini = 0.474\nsamples = 426\nvalue = [164, 262]'),
#  Text(0.4473684210526316, 0.8125, 'X[27] <= 0.136\ngini = 0.183\nsamples = 284\nvalue = [29, 255]'),
#  Text(0.2631578947368421, 0.6875, 'X[13] <= 45.17\ngini = 0.033\nsamples = 242\nvalue = [4, 238]'),
#  Text(0.15789473684210525, 0.5625, 'X[14] <= 0.003\ngini = 0.008\nsamples = 235\nvalue = [1, 234]'),
#  Text(0.10526315789473684, 0.4375, 'X[21] <= 27.755\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.05263157894736842, 0.3125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.15789473684210525, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.21052631578947367, 0.4375, 'gini = 0.0\nsamples = 230\nvalue = [0, 230]'),
#  Text(0.3684210526315789, 0.5625, 'X[15] <= 0.014\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.3157894736842105, 0.4375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.42105263157894735, 0.4375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.631578947368421, 0.6875, 'X[21] <= 27.575\ngini = 0.482\nsamples = 42\nvalue = [25, 17]'),
#  Text(0.5789473684210527, 0.5625, 'X[27] <= 0.187\ngini = 0.435\nsamples = 25\nvalue = [8, 17]'),
#  Text(0.5263157894736842, 0.4375, 'X[27] <= 0.139\ngini = 0.351\nsamples = 22\nvalue = [5, 17]'),
#  Text(0.47368421052631576, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5789473684210527, 0.3125, 'X[28] <= 0.358\ngini = 0.255\nsamples = 20\nvalue = [3, 17]'),
#  Text(0.47368421052631576, 0.1875, 'X[29] <= 0.073\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(0.42105263157894735, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5263157894736842, 0.0625, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(0.6842105263157895, 0.1875, 'X[3] <= 363.8\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.631578947368421, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7368421052631579, 0.0625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.631578947368421, 0.4375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6842105263157895, 0.5625, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.8947368421052632, 0.8125, 'X[7] <= 0.05\ngini = 0.094\nsamples = 142\nvalue = [135, 7]'),
#  Text(0.8421052631578947, 0.6875, 'X[17] <= 0.01\ngini = 0.484\nsamples = 17\nvalue = [10, 7]'),
#  Text(0.7894736842105263, 0.5625, 'X[1] <= 15.77\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.7368421052631579, 0.4375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8421052631578947, 0.4375, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.8947368421052632, 0.5625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9473684210526315, 0.6875, 'gini = 0.0\nsamples = 125\nvalue = [125, 0]')]

# %%
print("accuracy:",clf.score(x_test,y_test)*100)
# Out:
# accuracy: 95.8041958041958
